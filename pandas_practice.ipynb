# %% [markdown]
# # https://towardsdatascience.com/3-simple-ways-to-handle-large-data-with-pandas-d9164a3c02c1

# %%
import pandas as pd
import numpy as np
info=np.array(["p","a","n","d","a","s"])
a=pd.Series(info)
a
# Out:
# 0    p
# 1    a
# 2    n
# 3    d
# 4    a
# 5    s
# dtype: object

# %%
x=['python','pandas']
df=pd.DataFrame(x)
df
# Out:
#         0
# 0  python
# 1  pandas

# %%
s=pd.Series(["a","b","c"],name="vals")
s.to_frame()
# Out:
#   vals
# 0    a
# 1    b
# 2    c

# %%
emp=['Parkar','John','Smith','William']
id=[102,203,405,675]
emp_series=pd.Series(emp)
id_series=pd.Series(id)
frame={'EMP':emp_series,'ID':id_series}
result=pd.DataFrame(frame)

print(result)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-76a4aca0bdae> in <module>
#       5 frame={'EMP':emp_series,'ID':id_series}
#       6 result=pd.DataFrame(frame)
# ----> 7 table=pd.pivot_table(result)
#       8 print(table)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\reshape\pivot.py in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name)
#      79         values = list(values)
#      80
# ---> 81     grouped = data.groupby(keys, observed=False)
#      82     agged = grouped.agg(aggfunc)
#      83     if dropna and isinstance(agged, ABCDataFrame) and len(agged.columns):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, **kwargs)
# ...

# %%
index=pd.Index([1,3,2,2,1,np.nan])
index.value_counts(dropna=True)
# Out:
# 2.0    2
# 1.0    2
# 3.0    1
# dtype: int64

# %%
a_info=pd.DataFrame([[4,5],[6,7]],columns=['x','y'])
b_info=pd.DataFrame([[8,9],[10,11]],columns=['x','y'])
a_info=a_info.append(b_info)
#a_info=a_info.drop(0)
a_info
# Out:
#     x   y
# 0   4   5
# 1   6   7
# 0   8   9
# 1  10  11

# %%
import pandas as pd
df=pd.read_csv(r"C:\Users\priyabrata151056\Downloads\CallMiner_exploration\Search_report_1000_record1.csv")
df
# Out:
#      Eureka ID  Hits  Score.Percent Silence Score  \
# 0       437232   NaN                     0.544519
# 1       437239   NaN                     0.491066
# 2       437259   NaN                     0.289507
# 3       437262   NaN                     0.466677
# 4       437293   NaN                     0.170237
# 5       437301   NaN                     0.686993
# 6       437327   NaN                     0.392732
# 7       437333   NaN                     0.211160
# 8       437337   NaN                     0.362235
# 9       437340   NaN                     0.253613
# 10      437352   NaN                     0.769293
# 11      437356   NaN                     0.336705
# 12      437366   NaN                     0.682275
# 13      437368   NaN                     0.364592
# 14      437379   NaN                     0.479355
# 15      437382   NaN                     0.546571
# 16      437384   NaN                     0.829319
# 17      437398   NaN                     0.303898
# ...

# %%
df.loc[1]
# Out:
# Eureka ID                                                                  437239
# Hits                                                                          NaN
# Score.Percent Silence Score                                              0.491066
# Score.Percent Silence Score*                                             0.491066
# Agent ID                                                                 10191327
# Agent Tenure                                                  05/31/11 | 12:00 AM
# ANS Login                                                                     NaN
# Beg Sub Rev Amt                                                               NaN
# Call Class                                                      Business Services
# Call Date                                                        10/22/2020 12:00
# CALL ID                                                                  56166380
# ...

# %%
df.iloc[500:1000]
# Out:
#      Eureka ID  Hits  Score.Percent Silence Score  \
# 500     440264   NaN                     0.921063
# 501     440265   NaN                     0.253463
# 502     440266   NaN                     0.645425
# 503     440267   NaN                     0.286518
# 504     440268   NaN                     0.654712
# 505     440269   NaN                     0.213116
# 506     440270   NaN                     0.444802
# 507     440271   NaN                     0.413277
# 508     440272   NaN                     0.658312
# 509     440273   NaN                     0.577054
# 510     440274   NaN                     0.790424
# 511     440275   NaN                     0.343223
# 512     440276   NaN                     0.567000
# 513     440277   NaN                     0.552630
# 514     440278   NaN                     0.225497
# 515     440279   NaN                     0.223444
# 516     440280   NaN                     0.405537
# 517     440281   NaN                     0.360144
# ...

# %%
df.iloc[0:5,0:5]
# Out:
#    Eureka ID  Hits  Score.Percent Silence Score  Score.Percent Silence Score*  \
# 0     437232   NaN                     0.544519                      0.544519
# 1     437239   NaN                     0.491066                      0.491066
# 2     437259   NaN                     0.289507                      0.289507
# 3     437262   NaN                     0.466677                      0.466677
# 4     437293   NaN                     0.170237                      0.170237
#
#    Agent ID
# 0  10364835
# 1  10191327
# 2  10187125
# 3  10371099
# 4  10317932
